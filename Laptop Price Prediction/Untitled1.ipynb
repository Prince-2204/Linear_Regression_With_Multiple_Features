# %%
# Importing Warnings library to avoid unwanted warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing Useful Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

plt.style.use('seaborn')

# %%
# Loading the dataset
df = pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
# Renaming Some of the Columns
df = df.rename(columns={'brand':'Brand' , 'processor_brand':'Processor Brand'
                       
                  ,'processor_name' :'Processor Name',
                   'processor_gnrtn': 'Processor Generation',
                   'ram_gb':'Ram in Gb',
                    'ram_type':'Ram Type',
                    'ssd':'SSD',
                    'hdd':'HDD',
                    'graphic_card_gb':'Graphic card in Gb',
                    'rating':'Ratings'
                       })

# %%
df
# Out:
#       Brand Processor Brand Processor Name Processor Generation Ram in Gb  \
# 0      ASUS           Intel        Core i3                 10th      4 GB
# 1    Lenovo           Intel        Core i3                 10th      4 GB
# 2    Lenovo           Intel        Core i3                 10th      4 GB
# 3      ASUS           Intel        Core i5                 10th      8 GB
# 4      ASUS           Intel   Celeron Dual        Not Available      4 GB
# ..      ...             ...            ...                  ...       ...
# 818    ASUS             AMD        Ryzen 9        Not Available      4 GB
# 819    ASUS             AMD        Ryzen 9        Not Available      4 GB
# 820    ASUS             AMD        Ryzen 9        Not Available      4 GB
# 821    ASUS             AMD        Ryzen 9        Not Available      4 GB
# 822  Lenovo             AMD        Ryzen 5                 10th      8 GB
#
#     Ram Type      SSD      HDD       os  os_bit Graphic card in Gb  \
# 0       DDR4     0 GB  1024 GB  Windows  64-bit               0 GB
# 1       DDR4     0 GB  1024 GB  Windows  64-bit               0 GB
# 2       DDR4     0 GB  1024 GB  Windows  64-bit               0 GB
# 3       DDR4   512 GB     0 GB  Windows  32-bit               2 GB
# 4       DDR4     0 GB   512 GB  Windows  64-bit               0 GB
# ..       ...      ...      ...      ...     ...                ...
# 818     DDR4  1024 GB     0 GB  Windows  64-bit               0 GB
# 819     DDR4  1024 GB     0 GB  Windows  64-bit               0 GB
# 820     DDR4  1024 GB     0 GB  Windows  64-bit               4 GB
# 821     DDR4  1024 GB     0 GB  Windows  64-bit               4 GB
# 822     DDR4   512 GB     0 GB      DOS  64-bit               0 GB
#
#          weight     warranty Touchscreen msoffice   Price  Ratings  \
# 0        Casual  No warranty          No       No   34649  2 stars
# 1        Casual  No warranty          No       No   38999  3 stars
# 2        Casual  No warranty          No       No   39999  3 stars
# 3        Casual  No warranty          No       No   69990  3 stars
# 4        Casual  No warranty          No       No   26990  3 stars
# ..          ...          ...         ...      ...     ...      ...
# 818      Casual       1 year          No       No  135990  3 stars
# 819      Casual       1 year          No       No  144990  3 stars
# 820      Casual       1 year          No       No  149990  3 stars
# 821      Casual       1 year          No       No  142990  3 stars
# 822  ThinNlight  No warranty          No       No   57490  4 stars
#
#      Number of Ratings  Number of Reviews
# 0                    3                  0
# 1                   65                  5
# 2                    8                  1
# 3                    0                  0
# 4                    0                  0
# ..                 ...                ...
# 818                  0                  0
# 819                  0                  0
# 820                  0                  0
# 821                  0                  0
# 822                 18                  4
#
# [823 rows x 19 columns]

# %% [markdown]
# # Converting some string type columns into int

# %%
df['Ram in Gb'].str.split(" ")
# Out:
# 0      [4, GB]
# 1      [4, GB]
# 2      [4, GB]
# 3      [8, GB]
# 4      [4, GB]
#         ...
# 818    [4, GB]
# 819    [4, GB]
# 820    [4, GB]
# 821    [4, GB]
# 822    [8, GB]
# Name: Ram in Gb, Length: 823, dtype: object

# %%
df['Ram in Gb'] = df['Ram in Gb'].str.split(" ").str.get(0)

# %%
df['Ram in Gb'] = df['Ram in Gb'].astype(int)

# %%
df['SSD'].str.split(" ")
# Out:
# 0         [0, GB]
# 1         [0, GB]
# 2         [0, GB]
# 3       [512, GB]
# 4         [0, GB]
#           ...
# 818    [1024, GB]
# 819    [1024, GB]
# 820    [1024, GB]
# 821    [1024, GB]
# 822     [512, GB]
# Name: SSD, Length: 823, dtype: object

# %%
df['SSD'] = df['SSD'].str.split(" ").str.get(0)

# %%
df['SSD'] = df["SSD"].astype(int)

# %%
 df['HDD'].str.split(" ")
# Out:
# 0      [1024, GB]
# 1      [1024, GB]
# 2      [1024, GB]
# 3         [0, GB]
# 4       [512, GB]
#           ...
# 818       [0, GB]
# 819       [0, GB]
# 820       [0, GB]
# 821       [0, GB]
# 822       [0, GB]
# Name: HDD, Length: 823, dtype: object

# %%
df['HDD'] = df['HDD'].str.split(" ").str.get(0)

# %%
df['HDD'] = df['HDD'].astype(int)

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
df['os_bit'].str.split("-")
# Out:
# 0      [64, bit]
# 1      [64, bit]
# 2      [64, bit]
# 3      [32, bit]
# 4      [64, bit]
#          ...
# 818    [64, bit]
# 819    [64, bit]
# 820    [64, bit]
# 821    [64, bit]
# 822    [64, bit]
# Name: os_bit, Length: 823, dtype: object

# %%
df['os_bit'] = df['os_bit'].str.split("-").str.get(0)

# %%
df['os_bit'] = df['os_bit'].astype(int)

# %%
df['Graphic card in Gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
df['Graphic card in Gb'].str.split(" ")
# Out:
# 0      [0, GB]
# 1      [0, GB]
# 2      [0, GB]
# 3      [2, GB]
# 4      [0, GB]
#         ...
# 818    [0, GB]
# 819    [0, GB]
# 820    [4, GB]
# 821    [4, GB]
# 822    [0, GB]
# Name: Graphic card in Gb, Length: 823, dtype: object

# %%
df['Graphic card in Gb'] = df['Graphic card in Gb'].str.split(" ")

# %%
df['Graphic card in Gb'] = df['Graphic card in Gb'].str.get(0)

# %%
df
# Out:
#       Brand Processor Brand Processor Name Processor Generation  Ram in Gb  \
# 0      ASUS           Intel        Core i3                 10th          4
# 1    Lenovo           Intel        Core i3                 10th          4
# 2    Lenovo           Intel        Core i3                 10th          4
# 3      ASUS           Intel        Core i5                 10th          8
# 4      ASUS           Intel   Celeron Dual        Not Available          4
# ..      ...             ...            ...                  ...        ...
# 818    ASUS             AMD        Ryzen 9        Not Available          4
# 819    ASUS             AMD        Ryzen 9        Not Available          4
# 820    ASUS             AMD        Ryzen 9        Not Available          4
# 821    ASUS             AMD        Ryzen 9        Not Available          4
# 822  Lenovo             AMD        Ryzen 5                 10th          8
#
#     Ram Type   SSD   HDD       os  os_bit Graphic card in Gb      weight  \
# 0       DDR4     0  1024  Windows      64                  0      Casual
# 1       DDR4     0  1024  Windows      64                  0      Casual
# 2       DDR4     0  1024  Windows      64                  0      Casual
# 3       DDR4   512     0  Windows      32                  2      Casual
# 4       DDR4     0   512  Windows      64                  0      Casual
# ..       ...   ...   ...      ...     ...                ...         ...
# 818     DDR4  1024     0  Windows      64                  0      Casual
# 819     DDR4  1024     0  Windows      64                  0      Casual
# 820     DDR4  1024     0  Windows      64                  4      Casual
# 821     DDR4  1024     0  Windows      64                  4      Casual
# 822     DDR4   512     0      DOS      64                  0  ThinNlight
#
#         warranty Touchscreen msoffice   Price  Ratings  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
df['Graphic card in Gb'] = df['Graphic card in Gb'].astype(int)

# %%
df['Ratings'].str.split(" ")
# Out:
# 0      [2, stars]
# 1      [3, stars]
# 2      [3, stars]
# 3      [3, stars]
# 4      [3, stars]
#           ...
# 818    [3, stars]
# 819    [3, stars]
# 820    [3, stars]
# 821    [3, stars]
# 822    [4, stars]
# Name: Ratings, Length: 823, dtype: object

# %%
df['Ratings'] = df['Ratings'].str.split(" ").str.get(0)

# %%
df['Ratings'] = df['Ratings'].astype(int)

# %%
df.head()
# Out:
#     Brand Processor Brand Processor Name Processor Generation  Ram in Gb  \
# 0    ASUS           Intel        Core i3                 10th          4
# 1  Lenovo           Intel        Core i3                 10th          4
# 2  Lenovo           Intel        Core i3                 10th          4
# 3    ASUS           Intel        Core i5                 10th          8
# 4    ASUS           Intel   Celeron Dual        Not Available          4
#
#   Ram Type  SSD   HDD       os  os_bit  Graphic card in Gb  weight  \
# 0     DDR4    0  1024  Windows      64                   0  Casual
# 1     DDR4    0  1024  Windows      64                   0  Casual
# 2     DDR4    0  1024  Windows      64                   0  Casual
# 3     DDR4  512     0  Windows      32                   2  Casual
# 4     DDR4    0   512  Windows      64                   0  Casual
#
#       warranty Touchscreen msoffice  Price  Ratings  Number of Ratings  \
# 0  No warranty          No       No  34649        2                  3
# 1  No warranty          No       No  38999        3                 65
# 2  No warranty          No       No  39999        3                  8
# 3  No warranty          No       No  69990        3                  0
# 4  No warranty          No       No  26990        3                  0
#
#    Number of Reviews
# 0                  0
# 1                  5
# 2                  1
# 3                  0
# 4                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 823 non-null    object
#  1   Processor Brand       823 non-null    object
#  2   Processor Name        823 non-null    object
#  3   Processor Generation  823 non-null    object
#  4   Ram in Gb             823 non-null    int32
#  5   Ram Type              823 non-null    object
#  6   SSD                   823 non-null    int32
#  7   HDD                   823 non-null    int32
#  8   os                    823 non-null    object
#  9   os_bit                823 non-null    int32
#  10  Graphic card in Gb    823 non-null    int32
#  11  weight                823 non-null    object
#  12  warranty              823 non-null    object
#  13  Touchscreen           823 non-null    object
#  14  msoffice              823 non-null    object
#  15  Price                 823 non-null    int64
#  16  Ratings               823 non-null    int32
#  17  Number of Ratings     823 non-null    int64
#  18  Number of Reviews     823 non-null    int64
# dtypes: int32(6), int64(3), object(10)
# memory usage: 103.0+ KB

# %%
df.describe()
# Out:
#         Ram in Gb          SSD          HDD      os_bit  Graphic card in Gb  \
# count  823.000000   823.000000   823.000000  823.000000          823.000000
# mean     8.680437   452.121507   227.071689   59.761847            1.190765
# std      4.372408   316.662592   413.105282   10.853667            2.026902
# min      4.000000     0.000000     0.000000   32.000000            0.000000
# 25%      4.000000   256.000000     0.000000   64.000000            0.000000
# 50%      8.000000   512.000000     0.000000   64.000000            0.000000
# 75%      8.000000   512.000000     0.000000   64.000000            2.000000
# max     32.000000  3072.000000  2048.000000   64.000000            8.000000
#
#                Price     Ratings  Number of Ratings  Number of Reviews
# count     823.000000  823.000000         823.000000         823.000000
# mean    76745.177400    3.562576         315.301337          37.609964
# std     45101.790525    0.567282        1047.382654         121.728017
# min     16990.000000    1.000000           0.000000           0.000000
# 25%     46095.000000    3.000000           0.000000           0.000000
# 50%     64990.000000    4.000000          17.000000           2.000000
# 75%     89636.000000    4.000000         139.500000          18.000000
# max    441990.000000    5.000000       15279.000000        1947.000000

# %% [markdown]
# # Analyzing the dataset using various type of graphs

# %%
sns.distplot(df['Price'])
plt.show()

# %%
sns.countplot(x='Brand' , data=df)
plt.show()

# %%
sns.countplot(x='Processor Brand' , data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Processor Name' , data=df)
plt.show()

# %%
sns.countplot(x='Processor Generation' , data=df)
plt.show()

# %%
sns.countplot(x='weight' , data=df)
plt.show()

# %%
sns.countplot(x='warranty' , data=df)
plt.show()

# %%
sns.countplot(x='Ratings' , data=df)
plt.show()

# %%
sns.lineplot(x='SSD' , y='Price' , hue = 'weight' , data=df)
# Out:
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
sns.barplot(x='Brand' , y='Price' , data=df)
plt.show()

# %%
sns.boxplot(x='Price' , data=df)
# Out:
# <Axes: xlabel='Price'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(df)
plt.show()

# %%
df['Processor Generation'].replace('Not Available', df['Processor Generation'].mode()[0], inplace=True)

# %%
def remove_outlier_IQR(df, column):
    
    # sort values in ascending order in order to calculate the quartiles and the IQR 
    sorts = df[column].sort_values()
    
    Q1 = sorts.quantile(0.25)    #  25th percentile (first quartile)
    Q3 = sorts.quantile(0.75)    #  75th percentile (third quartile)
    IQR = Q3 - Q1
    
    lower_bound = sorts < (Q1-1.5*IQR)
    upper_bound = sorts > (Q3+1.5*IQR)
    # exlude rows from the dataframe above and below bounds
    df_final = df[~((lower_bound) | (upper_bound))].reset_index(drop=True)    
    
    return df_final

# %%
df = remove_outlier_IQR(df, "Price")
df = remove_outlier_IQR(df, "Number of Reviews")
df = remove_outlier_IQR(df, "Number of Ratings")

# %%
from sklearn import preprocessing

# %%
# Converting Object data types to Integer
for col in df.select_dtypes(include=['object']).columns:
    label_encoder = preprocessing.LabelEncoder()
    label_encoder.fit(df[col].unique())
    df[col] = label_encoder.transform(df[col])

# %%
df
# Out:
#      Brand  Processor Brand  Processor Name  Processor Generation  Ram in Gb  \
# 0        1                1               1                     0          4
# 1        5                1               1                     0          4
# 2        5                1               1                     0          4
# 3        1                1               2                     0          8
# 4        1                1               0                     1          4
# ..     ...              ...             ...                   ...        ...
# 547      1                0              10                     1          4
# 548      1                0              10                     1          4
# 549      1                0              10                     1          4
# 550      1                0              10                     1          4
# 551      5                0               8                     0          8
#
#      Ram Type   SSD   HDD  os  os_bit  Graphic card in Gb  weight  warranty  \
# 0           1     0  1024   2      64                   0       0         3
# 1           1     0  1024   2      64                   0       0         3
# 2           1     0  1024   2      64                   0       0         3
# 3           1   512     0   2      32                   2       0         3
# 4           1     0   512   2      64                   0       0         3
# ..        ...   ...   ...  ..     ...                 ...     ...       ...
# 547         1  1024     0   2      64                   0       0         0
# 548         1  1024     0   2      64                   0       0         0
# 549         1  1024     0   2      64                   4       0         0
# 550         1  1024     0   2      64                   4       0         0
# 551         1   512     0   0      64                   0       2         3
#
#      Touchscreen  msoffice   Price  Ratings  Number of Ratings  \
# 0              0         0   34649        2                  3
# 1              0         0   38999        3                 65
# 2              0         0   39999        3                  8
# 3              0         0   69990        3                  0
# 4              0         0   26990        3                  0
# ..           ...       ...     ...      ...                ...
# 547            0         0  135990        3                  0
# 548            0         0  144990        3                  0
# 549            0         0  149990        3                  0
# 550            0         0  142990        3                  0
# 551            0         0   57490        4                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 547                  0
# 548                  0
# 549                  0
# 550                  0
# 551                  4
#
# [552 rows x 19 columns]

# %%
# Plotting the Heatmap of the dataset
sns.heatmap(df)
# Out:
# <Axes: >

# %%
X = df[['Brand' , 'Processor Brand' , 'Processor Name' , 'Processor Generation' , 'Ram in Gb' ,'Ram Type' , 'SSD' , 'HDD' , 'os' ,'os_bit' , 'Graphic card in Gb' , 'weight' , 'warranty' , 'Touchscreen' ,'msoffice' , 'Ratings' , 'Number of Ratings','Number of Reviews']]

# %%
y = df['Price']

# %%
# Feature Scaling of X
def featurescaling(X):
    Xmean = X.mean(axis=0)
    Xstd = X.std(axis=0)
    
    return (X-Xmean)/Xstd

# %%
X = featurescaling(X)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 552 non-null    float64
#  1   Processor Brand       552 non-null    float64
#  2   Processor Name        552 non-null    float64
#  3   Processor Generation  552 non-null    float64
#  4   Ram in Gb             552 non-null    float64
#  5   Ram Type              552 non-null    float64
#  6   SSD                   552 non-null    float64
#  7   HDD                   552 non-null    float64
#  8   os                    552 non-null    float64
#  9   os_bit                552 non-null    float64
#  10  Graphic card in Gb    552 non-null    float64
#  11  weight                552 non-null    float64
#  12  warranty              552 non-null    float64
#  13  Touchscreen           552 non-null    float64
#  14  msoffice              552 non-null    float64
#  15  Ratings               552 non-null    float64
#  16  Number of Ratings     552 non-null    float64
#  17  Number of Reviews     552 non-null    float64
# dtypes: float64(18)
# memory usage: 77.8 KB

# %%
X.mean(axis=0)
# Out:
# Brand                  -7.401487e-17
# Processor Brand         5.148860e-17
# Processor Name         -5.148860e-17
# Processor Generation   -9.010506e-17
# Ram in Gb               0.000000e+00
# Ram Type               -9.010506e-17
# SSD                    -5.148860e-17
# HDD                    -7.079683e-17
# os                     -2.381348e-16
# os_bit                  2.316987e-16
# Graphic card in Gb      2.574430e-17
# weight                  3.861645e-17
# warranty                0.000000e+00
# Touchscreen             1.287215e-17
# msoffice                2.896234e-17
# Ratings                 1.576838e-16
# Number of Ratings       1.930823e-17
# Number of Reviews       8.366898e-17
# dtype: float64

# %%
X.std(axis=0)
# Out:
# Brand                   1.0
# Processor Brand         1.0
# Processor Name          1.0
# Processor Generation    1.0
# Ram in Gb               1.0
# Ram Type                1.0
# SSD                     1.0
# HDD                     1.0
# os                      1.0
# os_bit                  1.0
# Graphic card in Gb      1.0
# weight                  1.0
# warranty                1.0
# Touchscreen             1.0
# msoffice                1.0
# Ratings                 1.0
# Number of Ratings       1.0
# Number of Reviews       1.0
# dtype: float64

# %% [markdown]
# # Feature Selection

# %%
from sklearn.feature_selection import SelectKBest

# %%
best_features = SelectKBest(k = 'all')
fit = best_features.fit(X,y)

# %%
fit.scores_
# Out:
# array([1.033189  , 1.26901784, 1.57206642, 1.83084299, 1.59231637,
#        1.64731203, 3.31138963, 1.82199257, 3.38504294, 2.06721091,
#        1.57958055, 1.43345866, 1.51343252, 1.45122633, 1.22163726,
#        1.45282836, 0.91163332, 0.69132196])

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featurescore = pd.concat([dfcolumns , dfscores], axis= 1)

# %%
featurescore.columns = ['Feature Name' , 'Score']

# %%
featurescore
# Out:
#             Feature Name     Score
# 0                  Brand  1.033189
# 1        Processor Brand  1.269018
# 2         Processor Name  1.572066
# 3   Processor Generation  1.830843
# 4              Ram in Gb  1.592316
# 5               Ram Type  1.647312
# 6                    SSD  3.311390
# 7                    HDD  1.821993
# 8                     os  3.385043
# 9                 os_bit  2.067211
# 10    Graphic card in Gb  1.579581
# 11                weight  1.433459
# 12              warranty  1.513433
# 13           Touchscreen  1.451226
# 14              msoffice  1.221637
# 15               Ratings  1.452828
# 16     Number of Ratings  0.911633
# 17     Number of Reviews  0.691322

# %%
featurescore.sort_values(by="Score" , ascending = False)
# Out:
#             Feature Name     Score
# 8                     os  3.385043
# 6                    SSD  3.311390
# 9                 os_bit  2.067211
# 3   Processor Generation  1.830843
# 7                    HDD  1.821993
# 5               Ram Type  1.647312
# 4              Ram in Gb  1.592316
# 10    Graphic card in Gb  1.579581
# 2         Processor Name  1.572066
# 12              warranty  1.513433
# 15               Ratings  1.452828
# 13           Touchscreen  1.451226
# 11                weight  1.433459
# 1        Processor Brand  1.269018
# 14              msoffice  1.221637
# 0                  Brand  1.033189
# 16     Number of Ratings  0.911633
# 17     Number of Reviews  0.691322

# %% [markdown]
# # Applying Linear Regression Algorithm

# %%
Xtrain , Xtest , ytrain , ytest = train_test_split(X,y , test_size=0.3,random_state=101)

# %%
model = LinearRegression()

# %%
model.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(Xtest)

# %%
plt.scatter(ytest,y_predict,s=15)
plt.xlabel('Y Test(True Values)')
plt.ylabel('Predicted Values')
plt.plot(ytest, ytest, color='red', lw=1)

plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2 = r2_score(ytest,y_predict)

# %%
r2
# Out:
# 0.7058223996035542

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(ytest, y_predict))
print('MSE:', metrics.mean_squared_error(ytest, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(ytest, y_predict)))
# Out:
# MAE: 11271.813782934722
# MSE: 236030890.0986678
# RMSE: 15363.29684991694

# %%
print('Variance:', metrics.explained_variance_score(ytest, y_predict))
# Out:
# Variance: 0.7066849725423823

# %%
sns.displot((ytest-y_predict) , kde=True,bins=50)
plt.show()
